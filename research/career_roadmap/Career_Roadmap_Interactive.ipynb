# %% [markdown]
# # 🎯 Interactive Career Roadmap: Jonathan's Path to Oncolytic Virus R&D Leadership
#
# **Interactive Tool for Planning & Tracking Career Milestones (2025-2040)**
#
# This notebook allows you to:
# - Adjust timeline parameters dynamically
# - Visualize career phases and milestones
# - Track progress and update as circumstances change
# - Calculate financial projections
# - Export updated roadmaps

# %% [markdown]
# ---
#
# ## 📚 Detailed Phase Information
#
# <details>
# <summary><b>Click to expand: PHASE 0 - Finishing Strong at BYU (Nov 2025 - Apr 2026)</b></summary>
#
# ### Academic Priorities
# - **Target GPA**: Push for 3.4+ cumulative GPA (currently 3.32)
# - **Key Courses** (Winter 2026 - Final Semester):
#   - Take **Hematology** (relevant for lab career)
#   - Excel in **Immunology Lab** (MMBIO 467) - critical for oncolytic virus research
#   - Complete **Bioinformatics** (BIO 165) with strong performance
#   - Finish **Chemistry 106** and other remaining requirements
#
# ### Research & Laboratory Experience
# - **Continue undergraduate research** (MMBIO 294R, 399R, CHEM 297R):
#   - Aim for at least 2 years total diverse lab experience by graduation
#   - Seek opportunities to present research findings
#   - Request strong letters of recommendation from research mentors
# - **Flow Cytometry Proficiency**: Gain hands-on expertise (highly valued skill for cancer immunology research)
#
# ### Networking & Professional Development
# - **Attend office hours** regularly with professors in immunology/virology
# - **Present research** at undergraduate research symposia
# - **Build relationships** with faculty who could provide PhD recommendation letters later
# - **Join relevant student organizations** (pre-health, research clubs)
#
# ### Graduate School Preparation Begins
# - **Research PhD programs** in Cancer Biology, Virology, and Immunology
# - **Identify target institutions**: Mayo Clinic, Utah/Huntsman Cancer Institute, University of Pittsburgh, City of Hope, Duke
# - **Note your transcript gaps**: Organic Chemistry 1 (D grade), missing Ochem 2 and Biochemistry
#
# </details>
#
# <details>
# <summary><b>Click to expand: PHASE 1 - Industry Lab Work + Prerequisites (Apr 2026 - Dec 2027)</b></summary>
#
# **Timeline**: 1.5-2 years
# **Primary Goal**: Build professional laboratory expertise while fixing academic deficiencies
#
# **Strategic Rationale**: This phase focuses on gaining valuable lab experience while completing critical chemistry prerequisites. A predictable 9-5 schedule allows dedicated time for coursework without the added burden of maintaining certifications.
#
# ### Employment Strategy: Research Associate / Lab Technician
#
# **Why Industry Lab Instead of MLS?**
# - **Predictable 9-5 schedule**: More time and energy for prerequisite courses
# - **No certification burden**: Focus resources on chemistry courses and self-study
# - **Still builds lab skills**: Valuable for PhD applications
# - **Better work-life balance**: Reduces burnout risk during intensive study period
#
# **Target Employers** (Utah-based):
# - **Biotech**: ARUP Laboratories, Myriad Genetics, Recursion Pharmaceuticals
# - **University**: University of Utah core facilities, Huntsman Cancer Institute
# - **Research**: Contract research organizations (CROs)
#
# **Salary Range**: $50,000-65,000
#
# **Key Objectives**:
# - Gain hands-on laboratory experience (molecular biology, cell culture, assays)
# - Build relationships with supervisors for recommendation letters
# - Maintain consistent schedule for evening/weekend coursework
#
# ### Critical Chemistry Prerequisites (Primary Focus)
#
# **Priority 1: Retake Organic Chemistry 1** (Summer 2026)
# - **Provider**: UC San Diego Extended Studies (lecture only, 4.5 units)
# - **Cost**: $845
# - **Goal**: Replace D grade with B+ or higher
#
# **Priority 2: Complete Biochemistry** (Fall 2026)
# - **Provider**: UC San Diego Extended Studies (lecture only, 4.5 units)
# - **Cost**: $845
# - **Rationale**: Required/strongly recommended by most PhD programs
#
# **Priority 3: Organic Chemistry 2** (Spring 2027, if needed)
# - **Decision point**: Check target PhD program requirements
# - **Mayo Clinic VGT program**: More flexible, may not require Ochem 2
# - **Top cancer biology programs**: Typically require full year
# - **Cost**: $845
#
# **Total Chemistry Investment**: $1,690-2,535
#
# ### Additional Prerequisites (As Required by Target Programs)
#
# **Biological Sciences**:
# - Genetics: ~$600-900
# - Cell Biology: ~$600-900
# - Anatomy and Physiology: ~$600-900
#
# ### Self-Study Foundation Building
#
# **Mathematics (Khan Academy + YouTube)**
# - **Target**: 2-3 hours per week
# - **Focus Areas**: Calculus basics, Linear Algebra (3Blue1Brown series)
#
# **Cancer & Immunology Literature**
# - **Essential Textbooks**: "Oncoimmunology" by Zitvogel & Kroemer
# - **Premier Journals** (weekly reading): Nature Immunology, Nature Cancer
# - **Goal**: Build deep domain knowledge for PhD applications
#
# ### Coursera Specializations
#
# **Programming Foundation**
# - "Python for Genomic Data Science" (Johns Hopkins)
# - "R Programming" (Johns Hopkins)
#
# **Domain Expertise**
# - "Cancer Biology Specialization" (Johns Hopkins, 3-course series)
#
# **Total Coursera Investment**: ~$600-1,200
#
# ### Financial Planning
# - **Income**: $50,000-65,000 annual salary
# - **Expenses**: Chemistry courses $1,690-2,535, Additional prerequisites $1,000-4,000, Coursera $600-1,200
# - **Net**: Positive cash flow while building credentials
#
# </details>
#
# <details>
# <summary><b>Click to expand: PHASE 2 - MS Translational Bioinformatics + Industry Work (Jan 2028 - Dec 2029)</b></summary>
#
# **Timeline**: 2 years
# **Primary Goal**: Complete MS in Translational Bioinformatics while accumulating 3.8 years lab experience
#
# **Strategic Rationale**: This phase maximizes efficiency by completing a rigorous MS degree while maintaining full-time employment. The predictable 9-5 schedule makes balancing work and grad school more sustainable.
#
# ### MS Biomedical Informatics - Translational Bioinformatics Track - University of Utah (SELECTED)
#
# **Program Details**:
# - **Format**: Fully online, designed for working professionals
# - **Duration**: 2 years part-time (flexible pacing)
# - **Total Cost**: ~$24,000-30,000
# - **Curriculum**: Biomedical data science, genomics, computational biology, translational research methods, statistical genomics, precision medicine
# - **Strategic Advantages**:
#   - **Translational focus**: Directly aligned with cancer research goals
#   - **Utah connection**: Build relationships at Huntsman Cancer Institute (target PhD institution)
#   - **Networking**: Access to Huntsman Cancer Institute seminars and faculty
#   - **Perfect fit**: Translational bioinformatics = exactly what you need for oncolytic virus research
#
# **Why Translational Bioinformatics is Ideal for Your Goals**:
# This program bridges clinical research and computational biology - the perfect fit:
# - ✅ Python & R programming
# - ✅ Statistical modeling & hypothesis testing
# - ✅ Machine learning algorithms
# - ✅ Data visualization
# - ✅ Big data handling
# - ✅ Version control (Git)
#
# ### MS Program Strategy
#
# **Year 1 (2028)**:
# - Continue full-time lab work
# - Enroll in 1-2 courses per semester
# - Focus: Programming (Python/R), statistics, data structures
# - Maintain 3.7+ GPA for PhD competitiveness
#
# **Year 2 (2029)**:
# - Continue full-time lab work
# - Take 2 courses per semester
# - Focus: Machine learning, statistical modeling, data visualization
# - **CRITICAL - Capstone Focus**: Cancer genomics / oncolytic virus analysis
# - Target graduation: December 2029
#
# ### Bioinformatics Self-Study Supplements
#
# - **Rosalind Platform**: Free bioinformatics programming problems
# - **Coursera Bioinformatics Specialization** (UC San Diego)
# - **edX "Genomic Data Science"** (Johns Hopkins)
# - **Bioconductor tutorials**: R-based bioinformatics tools
#
# ### Capstone Strategy
# - Use publicly available cancer genomics datasets (TCGA, GEO, cBioPortal)
# - Apply data science techniques to biological questions
# - Focus on oncolytic virus research or cancer immunology
# - **Goal**: Publish as preprint or submit to journal
#
# ### Financial Planning
# - **Income**: $50,000-65,000 annual salary (with raises)
# - **Expenses**: MS tuition ~$7,500/year
# - **Net**: Strong cash flow; save for PhD relocation
#
# </details>
#
# <details>
# <summary><b>Click to expand: PHASE 3 - PhD Applications (2029-2030)</b></summary>
#
# **Timeline**: 1 year application cycle
# **Primary Goal**: Secure admission to top oncolytic virotherapy PhD program
#
# ### Application Timeline
#
# **Summer 2029** (June-August):
# - **Finalize program list**: 8-12 PhD programs in Cancer Biology, Virology, Immunology
# - **Target institutions**:
#   - **Mayo Clinic** - Virology & Gene Therapy track (top choice)
#   - **Utah/Huntsman Cancer Institute** - Cancer Biology (strong connection from MS!)
#   - **University of Pittsburgh** - Cancer Immunology
#   - City of Hope - Oncolytic Virus Center
#   - Duke University - Immunology
#   - Utah/Huntsman Cancer Institute - Cancer Biology
# - **Contact potential advisors**: Email PIs working on oncolytic virotherapy
# - **Leverage Pitt connection**: Reach out to faculty you met during MS program
# - **Request recommendation letters**: Line up 3-4 strong recommenders
#
# **Fall 2029** (September-December):
# - **Complete applications**: Most PhD programs deadline December 1-15
# - **GRE** (if required): Some programs waiving, but prepare if needed
# - **Personal statement**: Craft compelling narrative about your unique path
# - **Research statement**: Articulate specific oncolytic virus research interests
#
# **Winter/Spring 2030** (January-April):
# - **Interviews**: Virtual and in-person visits (Pitt interview = advantage!)
# - **Decision**: Accept offer by April 15 (National Decision Day)
# - **Prepare for transition**: Wind down lab work, relocate if needed
#
# ### Your Competitive Application Profile
#
# **Academic Credentials**:
# - **MS Translational Bioinformatics (University of Utah, GPA 3.7+)** with cancer genomics capstone
# - Improved chemistry grades (Ochem 1 retaken, Biochemistry completed)
# - Relevant coursework: Virology, Immunology, Molecular Biology, Data Science, Machine Learning
#
# **Research Experience**:
# - 2+ years undergraduate research (BYU)
# - **MS capstone on computational cancer biology / oncolytic virus analysis**
# - 3.8 years professional laboratory experience
# - Flow cytometry, molecular techniques, immunology protocols
#
# **Computational Skills**:
# - Programming: Python, R (demonstrated in MS coursework)
# - Data analysis: Statistical modeling, machine learning, data visualization
# - **Bioinformatics tools**: RNAseq analysis, genomic data analysis
#
# **Unique Narrative**:
# "I bring a rare combination of laboratory expertise, translational bioinformatics training, and passionate focus on oncolytic virotherapy. My 3.8 years as a Research Associate provided hands-on experience with molecular biology techniques. My MS in Translational Bioinformatics, with a capstone in cancer genomics, equipped me with computational tools for analyzing viral-tumor interactions. This dual wet lab/dry lab background positions me to accelerate oncolytic virus development."
#
# **Letters of Recommendation**:
# 1. **Utah MS advisor/capstone mentor** (computational research abilities)
# 2. Work supervisor (technical proficiency)
# 3. BYU research mentor (undergraduate research foundation)
#
# </details>
#
# <details>
# <summary><b>Click to expand: PHASE 4 - PhD Training (2030-2035/2036)</b></summary>
#
# **Timeline**: 5-6 years
# **Primary Goal**: Become expert in oncolytic virus research with translational focus
#
# ### Example Program: Mayo Clinic Virology & Gene Therapy Track
#
# **Year 1 (2030-2031): Core Training**
# - Three 6-week laboratory rotations
#   - Rotation 1: Viral vector engineering
#   - Rotation 2: Cancer immunology/tumor microenvironment
#   - Rotation 3: Computational biology/bioinformatics
# - Core curriculum courses
# - Written qualifying exam (end of Year 1)
#
# **Year 2 (2031-2032): Thesis Lab Selection & Qualification**
# - Select thesis advisor working on oncolytic virotherapy
# - Oral qualifying exam
# - Begin dissertation research project
# - Publish first co-authored paper
#
# **Years 3-5 (2032-2035): Dissertation Research**
# - Execute comprehensive oncolytic virus research project
# - Target 3-5 first-author publications
# - Present at national conferences (AACR, SITC, ASH)
# - Mentor rotating students
#
# **Year 5-6 (2035-2036): Dissertation Writing & Defense**
# - Write dissertation chapters
# - Dissertation defense
# - Graduate with PhD
#
# ### Leveraging Your Data Science MS
#
# **Unique Research Approaches**:
# - Integrate computational modeling with experimental virology
# - Use machine learning to predict optimal virus-tumor matches
# - Analyze single-cell RNAseq from virus-infected tumors
#
# **Value Proposition**: You'll be among few PhD students who can independently execute both wet lab experiments AND dry lab analyses
#
# ### Professional Development During PhD
# - **Teaching**: TA for immunology or virology courses
# - **Grants**: Apply for F31 predoctoral fellowship (NIH)
# - **Industry exposure**: Summer internships at biotech companies
# - **Networking**: Build relationships with translational scientists
#
# </details>
#
# <details>
# <summary><b>Click to expand: PHASE 5 - Industry Career (2035/2036+)</b></summary>
#
# **Timeline**: Long-term career
# **Primary Goal**: Lead oncolytic virus R&D programs while maintaining academic connection
#
# ### Primary Career Path: Translational Scientist in Biotech
#
# **Entry Level (Years 1-3): Scientist I/II**
# - Join oncolytic virus company or cancer immunotherapy biotech
# - Lead projects bridging lab discovery to clinical trials
# - Salary: $110,000-140,000
#
# **Mid-Career (Years 4-8): Senior Scientist**
# - Manage cross-functional teams
# - Design preclinical studies for IND applications
# - Salary: $140,000-180,000
#
# **Senior Leadership (Years 9+): Principal Scientist / Director of R&D**
# - Lead entire oncolytic virus program
# - Strategic decision-making for pipeline development
# - Salary: $180,000-250,000+
#
# ### Secondary Career Path: Adjunct Professor
#
# **Concurrent with Industry Role**:
# - Teach 1-2 courses per year at local university
# - Typical courses: Virology, Cancer Biology, Data Science
# - Salary: $3,000-6,000 per course
#
# ### Long-Term Impact Goals
# - Advance oncolytic virotherapy toward more effective cancer treatments
# - Publish 30-50+ papers over career
# - Train dozens of scientists through industry and academic teaching
# - Contribute to FDA-approved oncolytic virus therapies
#
# </details>
#
# <details>
# <summary><b>Click to expand: Your Competitive Advantages</b></summary>
#
# ### What Makes You Unique
#
# **1. Computational-Research Dual Expertise**
# - Most PhD candidates lack computational sophistication
# - Most data scientists lack wet lab proficiency
# - **You'll have both**
#
# **2. Mature Candidate with Real-World Experience**
# - 3.8 years professional laboratory work before PhD
# - Bring project management and professional communication skills
# - More prepared than typical 22-year-old PhD student
#
# **3. Clear Career Vision**
# - Specific focus (oncolytic virotherapy) from early stage
# - Coherent narrative connecting all experiences
# - Demonstrates sustained commitment to field
#
# **4. Financial Stability**
# - No undergraduate debt concerns
# - Positive cash flow during MS program
# - Savings buffer for PhD stipend years
# - Lower expenses without certification burden
# **5. Strategic Utah Connection**
# - MS from Huntsman Cancer Institute's home university
# - Established relationships with Utah faculty
# - Inside track for Huntsman PhD program
# - Inside track for Pitt PhD program
#
# **6. Sustainable Pace**
# - 9-5 job allows dedicated study time
# - Less mental load = better chemistry course performance
# - Reduced burnout risk
#
# </details>
#
# <details>
# <summary><b>Click to expand: Contingency Plans & Success Factors</b></summary>
#
# ### Contingency Plans
#
# **If Chemistry Prerequisites Prove Too Difficult**
# - Focus on retaking Ochem 1 only (skip Ochem 2)
# - Target PhD programs with more flexible requirements (Mayo Clinic VGT)
# - Emphasize computational strengths and lab experience
# **If MS Translational Bioinformatics Becomes Too Demanding**
# - Extend timeline to 2.5-3 years part-time
# - Reduce course load to 1 per semester
# - Consider terminal MS without capstone
#
# **If PhD Admissions Unsuccessful First Cycle**
# - Continue lab work + complete MS if not finished
# - Strengthen application with capstone publication
# - Reapply following year with stronger profile
#
# **If Industry Jobs Scarce Post-PhD**
# - Pursue postdoc at top institution (2-3 years)
# - Consider adjacent fields (gene therapy, vaccine development, CAR-T)
# - Leverage data science skills for computational biology roles
#
# ### Critical Success Factors
#
# **Academic Excellence**
# - Maintain 3.7+ GPA in MS Translational Bioinformatics
# - Replace D in Ochem 1 with B+ or higher
# - Excel in PhD coursework and qualifying exams
#
# **Research Productivity**
# - **Publish MS capstone** as preprint or in journal
# - Target 3-5 first-author PhD publications
# - Present at national conferences regularly
#
# **Skill Development**
# - Master wet lab: Cell culture, molecular biology, flow cytometry
# - Master dry lab: Python, R, machine learning, statistical modeling
# - Become true "dual-threat" translational scientist
#
# **Networking & Relationships**
# - Build strong mentor relationships (especially at Pitt!)
# - Maintain professional network throughout career
# - Connect with industry scientists at conferences
#
# </details>
#
# <details>
# <summary><b>Click to expand: 🧘 Self-Care & Sustainability Strategy</b></summary>
#
# ### Why This Matters
#
# Your roadmap spans **10+ years of intensive training**. Burnout is a real risk when juggling work, MS coursework, and self-study. **Sustainability > speed**.
#
# **Critical truth**: Starting PhD at 32 instead of 31 is negligible. Burning out at 30 and abandoning your goals is catastrophic.
#
# ---
#
# ### Core Non-Negotiables
#
# - **Sleep**: 7-8 hours minimum
# - **Exercise**: 3x/week minimum, even 20-30 min walks
# - **Social connection**: Isolation accelerates burnout
# - **Mental health**: Use counseling proactively
#
# ---
#
# ### Phase-Specific Strategies
#
# **Phase 1 (2026-2027): Building Sustainable Habits**
# - Predictable 9-5 schedule = evenings free for study
# - Don't overcommit to Coursera - 1-2 courses at a time max
# - Take 1 week completely off between Ochem 1 and Biochemistry
# - **Quarterly check**: Am I sleeping well? Is this pace sustainable?
#
# **Phase 2 (2028-2029): MS + Work Balance**
# - Use ALL your PTO for finals/capstone deadlines
# - Take 1-2 weeks off between semesters
# - Accept 3.7-3.8 GPA is excellent
# - **Warning signs**: Chronic exhaustion, frequent illness, loss of interest
# - **Emergency adjustment**: Extend MS to 2.5 years if needed
#
# **Phase 3 (2029-2030): PhD Applications**
# - Set boundaries: 2-3 hours/day on apps max
# - **Program selection**: Lab culture > prestige
# - **Consider**: 3-6 month gap before PhD to recharge
#
# **Phase 4 (2030-2035/36): PhD Sustainability**
# - Set sustainable boundaries early
# - Regular therapy, maintain hobbies, stay connected
# - Protect dissertation writing time
# - **Quarterly check**: Still excited or just grinding?
#
# ---
#
# ### Your Advantages
#
# - **Maturity**: At 31+ you'll have better self-awareness than typical PhD students
# - **Financial security**: No debt + savings = less stress
# - **Clear purpose**: Oncolytic virotherapy passion = intrinsic motivation
# - **Backup plan**: MS + lab experience = solid career foundation
#
# ---
#
# ### Support Resources
#
# **Professional**: Find mentor, join r/GradSchool, ASM/AACR organizations
#
# **Personal**: Maintain 1-2 close friendships, family check-ins
#
# **Crisis**:
# - University counseling (free for students)
# - National Suicide Prevention: 988
# - Crisis Text Line: HOME to 741741
#
# ---
#
# ### Remember
#
# **Your timeline is a plan, not a prison.** Extending any phase by 6 months won't derail goals. **Burning out is irreversible.**
#
# </details>

# %%
# Install required packages (run once)
# !pip install pandas matplotlib plotly ipywidgets
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import ipywidgets as widgets
from IPython.display import display, HTML, Markdown
import numpy as np

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %% [markdown]
# ## 📊 Part 1: Timeline Configuration
#
# Adjust these parameters to customize your roadmap timeline.

# %%
# ========== ADJUSTABLE PARAMETERS ==========

# Personal Information
BIRTH_YEAR = 1999
GRADUATION_DATE = datetime(2026, 4, 1)  # April 2026

# Phase 1: Industry Lab Work + Prerequisites
PHASE1_DURATION_MONTHS = 21  # 1.5-2 years (adjustable: 18-24 months)

# Phase 2: MS Translational Bioinformatics (University of Utah)
MS_DURATION_YEARS = 2  # (adjustable: 2-3 years)

# Phase 3: PhD Program
PHD_DURATION_YEARS = 5.5  # (adjustable: 5-6 years)

# Phase 4: Postdoc (optional)
SKIP_POSTDOC = True  # Set to False if planning postdoc
POSTDOC_DURATION_YEARS = 2  # Only applies if SKIP_POSTDOC = False

# Financial Parameters
LAB_STARTING_SALARY = 50000  # Research Associate / Lab Tech starting salary
LAB_ANNUAL_RAISE_PCT = 5.0  # Conservative raises for industry lab work
MS_ANNUAL_TUITION = 12000  # University of Utah MS Biomedical Informatics (Translational Bioinformatics): ~$24K total / 2 years
PHD_STIPEND = 32000
SCIENTIST_STARTING_SALARY = 125000

print("📋 Configuration loaded!")
print(f"Current age: {datetime.now().year - BIRTH_YEAR}")
print(f"Age at graduation: {GRADUATION_DATE.year - BIRTH_YEAR}")
# Out:
# 📋 Configuration loaded!
# Current age: 26
# Age at graduation: 27

# %% [markdown]
# ## 🗓️ Part 2: Calculate Timeline Milestones

# %%
def calculate_timeline():
    """
    Calculate all major career milestones based on configuration parameters.
    """
    milestones = {}
    
    # Phase 0: Current to Graduation
    milestones['graduation'] = GRADUATION_DATE
    milestones['graduation_age'] = GRADUATION_DATE.year - BIRTH_YEAR
    
    # Phase 1: Industry Lab Work + Prerequisites
    phase1_start = GRADUATION_DATE
    phase1_end = phase1_start + relativedelta(months=PHASE1_DURATION_MONTHS)
    milestones['phase1_start'] = phase1_start
    milestones['phase1_end'] = phase1_end
    milestones['phase1_start_age'] = phase1_start.year - BIRTH_YEAR
    milestones['phase1_end_age'] = phase1_end.year - BIRTH_YEAR
    
    # Phase 2: MS Translational Bioinformatics
    ms_start = phase1_end + relativedelta(months=1)
    ms_end = ms_start + relativedelta(months=int(MS_DURATION_YEARS * 12))
    milestones['ms_start'] = ms_start
    milestones['ms_end'] = ms_end
    milestones['ms_start_age'] = ms_start.year - BIRTH_YEAR
    milestones['ms_end_age'] = ms_end.year - BIRTH_YEAR
    
    # Calculate total lab experience
    lab_years = (ms_end.year - phase1_start.year) + (ms_end.month - phase1_start.month) / 12
    milestones['total_lab_years'] = round(lab_years, 1)
    
    # Phase 3: PhD Applications & Start
    phd_apply_start = ms_end - relativedelta(months=6)  # Apply 6 months before MS end
    phd_start = ms_end + relativedelta(months=8)  # Start following fall
    phd_end = phd_start + relativedelta(months=int(PHD_DURATION_YEARS * 12))
    milestones['phd_apply_start'] = phd_apply_start
    milestones['phd_start'] = phd_start
    milestones['phd_end'] = phd_end
    milestones['phd_start_age'] = phd_start.year - BIRTH_YEAR
    milestones['phd_end_age'] = phd_end.year - BIRTH_YEAR
    
    # Phase 4: Postdoc (optional)
    if SKIP_POSTDOC:
        career_start = phd_end + relativedelta(months=2)
        milestones['postdoc'] = False
    else:
        postdoc_start = phd_end + relativedelta(months=2)
        postdoc_end = postdoc_start + relativedelta(months=int(POSTDOC_DURATION_YEARS * 12))
        career_start = postdoc_end + relativedelta(months=2)
        milestones['postdoc'] = True
        milestones['postdoc_start'] = postdoc_start
        milestones['postdoc_end'] = postdoc_end
        milestones['postdoc_start_age'] = postdoc_start.year - BIRTH_YEAR
        milestones['postdoc_end_age'] = postdoc_end.year - BIRTH_YEAR
    
    # Phase 5: Industry Career Start
    milestones['industry_start'] = career_start
    milestones['industry_start_age'] = career_start.year - BIRTH_YEAR
    
    # Future projections
    milestones['senior_scientist'] = career_start + relativedelta(years=5)
    milestones['senior_scientist_age'] = milestones['senior_scientist'].year - BIRTH_YEAR
    milestones['principal_scientist'] = career_start + relativedelta(years=10)
    milestones['principal_scientist_age'] = milestones['principal_scientist'].year - BIRTH_YEAR
    
    return milestones

# Calculate timeline
timeline = calculate_timeline()

print("✅ Timeline calculated!")
print(f"\n📅 Key Milestones:")
print(f"  • Graduation: {timeline['graduation'].strftime('%B %Y')} (age {timeline['graduation_age']})")
print(f"  • MS Completion: {timeline['ms_end'].strftime('%B %Y')} (age {timeline['ms_end_age']})")
print(f"  • Total Lab Experience: {timeline['total_lab_years']} years")
print(f"  • PhD Start: {timeline['phd_start'].strftime('%B %Y')} (age {timeline['phd_start_age']})")
print(f"  • PhD Completion: {timeline['phd_end'].strftime('%B %Y')} (age {timeline['phd_end_age']})")
print(f"  • Industry Career Start: {timeline['industry_start'].strftime('%B %Y')} (age {timeline['industry_start_age']})")
# Out:
# ✅ Timeline calculated!
#
# 📅 Key Milestones:
#   • Graduation: April 2026 (age 27)
#   • MS Completion: February 2030 (age 31)
#   • Total Lab Experience: 3.8 years
#   • PhD Start: October 2030 (age 31)
#   • PhD Completion: April 2036 (age 37)
#   • Industry Career Start: June 2036 (age 37)

# %% [markdown]
# ## 📈 Part 3: Interactive Timeline Visualization

# %%
def create_gantt_chart(timeline):
    """
    Create an interactive Gantt chart showing all career phases.
    """
    # Prepare data for Gantt chart
    phases = []
    
    # Phase 0: Finishing BYU
    phases.append(dict(
        Task="Phase 0: Finishing BYU",
        Start=datetime.now(),
        Finish=timeline['graduation'],
        Resource="Education"
    ))
    
    # Phase 1: Industry Lab Work + Prerequisites
    phases.append(dict(
        Task="Phase 1: Lab Work + Prerequisites",
        Start=timeline['phase1_start'],
        Finish=timeline['phase1_end'],
        Resource="Work + Prerequisites"
    ))
    
    # Phase 2: MS Translational Bioinformatics
    phases.append(dict(
        Task="Phase 2: MS Translational Bioinformatics (Part-Time)",
        Start=timeline['ms_start'],
        Finish=timeline['ms_end'],
        Resource="Education + Work"
    ))
    
    # Phase 3: PhD Applications
    phases.append(dict(
        Task="Phase 3: PhD Applications",
        Start=timeline['phd_apply_start'],
        Finish=timeline['phd_start'],
        Resource="Transition"
    ))
    
    # Phase 4: PhD Program
    phases.append(dict(
        Task="Phase 4: PhD in Oncolytic Virotherapy",
        Start=timeline['phd_start'],
        Finish=timeline['phd_end'],
        Resource="Education"
    ))
    
    # Phase 5: Postdoc (if applicable)
    if timeline['postdoc']:
        phases.append(dict(
            Task="Phase 5: Postdoctoral Training",
            Start=timeline['postdoc_start'],
            Finish=timeline['postdoc_end'],
            Resource="Research"
        ))
    
    # Phase 6: Industry Career
    phases.append(dict(
        Task="Phase 5: Industry Scientist",
        Start=timeline['industry_start'],
        Finish=timeline['senior_scientist'],
        Resource="Career"
    ))
    
    phases.append(dict(
        Task="Senior Scientist Level",
        Start=timeline['senior_scientist'],
        Finish=timeline['principal_scientist'],
        Resource="Career"
    ))
    
    # Create DataFrame
    df = pd.DataFrame(phases)
    
    # Define colors for different resource types
    colors = {
        'Education': '#3498db',
        'Work + Prerequisites': '#e67e22',
        'Education + Work': '#9b59b6',
        'Transition': '#95a5a6',
        'Research': '#1abc9c',
        'Career': '#27ae60'
    }
    
    # Create Gantt chart
    fig = px.timeline(
        df,
        x_start="Start",
        x_end="Finish",
        y="Task",
        color="Resource",
        color_discrete_map=colors,
        title="Career Roadmap Timeline (2025-2045)"
    )
    
    # Set explicit category order to maintain chronological sequence
    category_order = [
        "Phase 0: Finishing BYU",
        "Phase 1: Lab Work + Prerequisites",
        "Phase 2: MS Translational Bioinformatics (Part-Time)",
        "Phase 3: PhD Applications",
        "Phase 4: PhD in Oncolytic Virotherapy",
        "Phase 5: Postdoctoral Training",
        "Phase 5: Industry Scientist",
        "Senior Scientist Level"
    ]
    
    fig.update_layout(
        height=600,
        xaxis_title="Year",
        yaxis_title="Career Phase",
        showlegend=True,
        hovermode='closest',
        yaxis={'categoryorder': 'array', 'categoryarray': category_order}
    )
    
    return fig

# Create and display Gantt chart
gantt_fig = create_gantt_chart(timeline)
gantt_fig.show()

# %% [markdown]
# ## 💰 Part 4: Financial Projections

# %%
def calculate_finances(timeline):
    """
    Calculate income, expenses, and net cash flow throughout the timeline.
    """
    financial_data = []
    
    # Phase 1 & 2: Industry Lab Work (with raises)
    lab_start_year = timeline['phase1_start'].year
    phd_start_year = timeline['phd_start'].year
    
    current_salary = LAB_STARTING_SALARY
    # Only include years before PhD starts
    for year in range(lab_start_year, phd_start_year):
        # Determine if in MS program (has tuition)
        in_ms = year >= timeline['ms_start'].year and year < timeline['ms_end'].year
        tuition = MS_ANNUAL_TUITION if in_ms else 0
        
        # Add chemistry course costs in first year
        other_expenses = 4000 if year == lab_start_year else 500
        
        financial_data.append({
            'Year': year,
            'Age': year - BIRTH_YEAR,
            'Phase': 'Lab Work + MS' if in_ms else 'Lab Work + Prerequisites',
            'Income': current_salary,
            'Tuition': tuition,
            'Other_Expenses': other_expenses,
            'Net': current_salary - tuition - other_expenses
        })
        
        # Annual raise
        current_salary *= (1 + LAB_ANNUAL_RAISE_PCT / 100)
    
    # Phase 4: PhD Years
    phd_end_year = timeline['phd_end'].year
    
    for year in range(phd_start_year, phd_end_year + 1):
        financial_data.append({
            'Year': year,
            'Age': year - BIRTH_YEAR,
            'Phase': 'PhD Program',
            'Income': PHD_STIPEND,
            'Tuition': 0,  # Fully funded
            'Other_Expenses': 500,
            'Net': PHD_STIPEND - 500
        })
    
    # Phase 5: Postdoc (if applicable)
    if timeline['postdoc']:
        postdoc_start_year = timeline['postdoc_start'].year
        postdoc_end_year = timeline['postdoc_end'].year
        for year in range(postdoc_start_year, postdoc_end_year + 1):
            financial_data.append({
                'Year': year,
                'Age': year - BIRTH_YEAR,
                'Phase': 'Postdoc',
                'Income': 60000,
                'Tuition': 0,
                'Other_Expenses': 500,
                'Net': 60000 - 500
            })
    
    # Phase 6: Industry Career (first 5 years)
    industry_start_year = timeline['industry_start'].year
    scientist_salary = SCIENTIST_STARTING_SALARY
    
    for year in range(industry_start_year, industry_start_year + 5):
        financial_data.append({
            'Year': year,
            'Age': year - BIRTH_YEAR,
            'Phase': 'Industry Scientist',
            'Income': scientist_salary,
            'Tuition': 0,
            'Other_Expenses': 1000,  # Professional development
            'Net': scientist_salary - 1000
        })
        scientist_salary *= 1.05  # 5% annual raises
    
    df_finance = pd.DataFrame(financial_data)
    df_finance['Cumulative_Net'] = df_finance['Net'].cumsum()
    
    return df_finance

# Calculate finances
df_finances = calculate_finances(timeline)

# Display summary
total_education_cost = df_finances['Tuition'].sum() + df_finances['Other_Expenses'].sum()
total_income = df_finances['Income'].sum()
final_net = df_finances['Cumulative_Net'].iloc[-1]

print("💰 Financial Summary:")
print(f"  • Total Education Investment: ${total_education_cost:,.0f}")
print(f"  • Total Income During Training: ${total_income:,.0f}")
print(f"  • Cumulative Net by Industry Start: ${final_net:,.0f}")

# Display first few rows
display(df_finances.head(10))
# Out:
# 💰 Financial Summary:
#   • Total Education Investment: $29,000
#   • Total Income During Training: $1,130,210
#   • Cumulative Net by Industry Start: $1,101,210
#    Year  Age                     Phase    Income  Tuition  Other_Expenses  \
# 0  2026   27  Lab Work + Prerequisites  50000.00        0            4000
# 1  2027   28  Lab Work + Prerequisites  52500.00        0             500
# 2  2028   29             Lab Work + MS  55125.00     7500             500
# 3  2029   30             Lab Work + MS  57881.25     7500             500
# 4  2030   31               PhD Program  32000.00        0             500
# 5  2031   32               PhD Program  32000.00        0             500
# 6  2032   33               PhD Program  32000.00        0             500
# 7  2033   34               PhD Program  32000.00        0             500
# 8  2034   35               PhD Program  32000.00        0             500
# ...

# %%
# Visualize financial trajectory
fig_finance = go.Figure()

# Income line
fig_finance.add_trace(go.Scatter(
    x=df_finances['Year'],
    y=df_finances['Income'],
    name='Annual Income',
    mode='lines+markers',
    line=dict(color='#27ae60', width=2)
))

# Net income line
fig_finance.add_trace(go.Scatter(
    x=df_finances['Year'],
    y=df_finances['Net'],
    name='Net Income (After Expenses)',
    mode='lines+markers',
    line=dict(color='#3498db', width=2)
))

# Cumulative net line
fig_finance.add_trace(go.Scatter(
    x=df_finances['Year'],
    y=df_finances['Cumulative_Net'],
    name='Cumulative Net Worth',
    mode='lines+markers',
    line=dict(color='#e74c3c', width=3, dash='dash')
))

fig_finance.update_layout(
    title='Financial Trajectory Over Career Timeline',
    xaxis_title='Year',
    yaxis_title='Amount ($)',
    height=500,
    hovermode='x unified',
    yaxis=dict(tickformat='$,.0f')
)

fig_finance.show()

# %% [markdown]
# ## 🎮 Part 5: Interactive Timeline Adjuster
#
# Use the sliders below to adjust timeline parameters and see how they affect your roadmap in real-time!

# %%
# Create interactive widgets with validation
style = {'description_width': '200px'}

phase1_slider = widgets.IntSlider(
    value=PHASE1_DURATION_MONTHS,
    min=12,
    max=36,
    step=3,
    description='Phase 1 Duration (months):',
    style=style,
    continuous_update=False
)

ms_slider = widgets.FloatSlider(
    value=MS_DURATION_YEARS,
    min=2.0,
    max=5.0,
    step=0.5,
    description='MS Duration (years):',
    style=style,
    continuous_update=False
)

phd_slider = widgets.FloatSlider(
    value=PHD_DURATION_YEARS,
    min=4.5,
    max=7.0,
    step=0.5,
    description='PhD Duration (years):',
    style=style,
    continuous_update=False
)

postdoc_checkbox = widgets.Checkbox(
    value=not SKIP_POSTDOC,
    description='Include Postdoc?',
    style=style
)

output = widgets.Output()
validation_output = widgets.Output()

def validate_inputs():
    """Validate timeline parameters and show warnings for unrealistic values."""
    warnings = []
    
    # Validate Phase 1 duration
    if phase1_slider.value < 15:
        warnings.append("⚠️ Phase 1 < 15 months may not allow enough time for chemistry prerequisites")
    
    # Validate MS duration
    if ms_slider.value < 2.0:
        warnings.append("⚠️ MS < 2 years is extremely aggressive for part-time study while working full-time")
    
    # Validate PhD duration
    if phd_slider.value < 5.0:
        warnings.append("⚠️ PhD < 5 years is ambitious; most programs average 5.5-6 years")
    elif phd_slider.value > 6.5:
        warnings.append("⚠️ PhD > 6.5 years may impact funding and career momentum")
    
    # Calculate total lab years
    temp_timeline = calculate_timeline()
    lab_years = temp_timeline['total_lab_years']
    
    if lab_years < 2.5:
        warnings.append(f"⚠️ Total lab experience ({lab_years:.1f} years) < 2.5 years may weaken PhD application")
    
    # Check age at industry start
    industry_age = temp_timeline['industry_start_age']
    if industry_age > 40:
        warnings.append(f"⚠️ Industry career start at age {industry_age} is quite late; consider shortening timeline")
    
    return warnings

def update_timeline(change):
    """Update timeline when widgets change with validation."""
    global PHASE1_DURATION_MONTHS, MS_DURATION_YEARS, PHD_DURATION_YEARS, SKIP_POSTDOC
    
    PHASE1_DURATION_MONTHS = phase1_slider.value
    MS_DURATION_YEARS = ms_slider.value
    PHD_DURATION_YEARS = phd_slider.value
    SKIP_POSTDOC = not postdoc_checkbox.value
    
    # Recalculate timeline
    new_timeline = calculate_timeline()
    
    # Display validation warnings
    with validation_output:
        validation_output.clear_output(wait=True)
        warnings = validate_inputs()
        if warnings:
            print("\n".join(warnings))
            print()
    
    # Display timeline update
    with output:
        output.clear_output(wait=True)
        
        print("🔄 Updated Timeline:")
        print(f"  • MS Completion: {new_timeline['ms_end'].strftime('%B %Y')} (age {new_timeline['ms_end_age']})")
        print(f"  • Total Lab Experience: {new_timeline['total_lab_years']} years")
        print(f"  • PhD Start: {new_timeline['phd_start'].strftime('%B %Y')} (age {new_timeline['phd_start_age']})")
        print(f"  • PhD Completion: {new_timeline['phd_end'].strftime('%B %Y')} (age {new_timeline['phd_end_age']})")
        print(f"  • Industry Start: {new_timeline['industry_start'].strftime('%B %Y')} (age {new_timeline['industry_start_age']})")
        print(f"\n  ⏱️  Time to Industry Career: {new_timeline['industry_start'].year - datetime.now().year} years from now")

# Attach update function to widgets
phase1_slider.observe(update_timeline, 'value')
ms_slider.observe(update_timeline, 'value')
phd_slider.observe(update_timeline, 'value')
postdoc_checkbox.observe(update_timeline, 'value')

# Display widgets
display(widgets.VBox([
    widgets.HTML("<h3>🎯 Adjust Timeline Parameters</h3>"),
    phase1_slider,
    ms_slider,
    phd_slider,
    postdoc_checkbox,
    validation_output,
    output
]))

# Trigger initial display
update_timeline(None)

# %% [markdown]
# ## 📋 Part 6: Milestone Checklist & Progress Tracker

# %%
# Define detailed milestones with checkboxes
milestones_checklist = {
    "Phase 0: Finishing BYU (Nov 2025 - Apr 2026)": [
        "Complete Winter 2026 courses (Hematology, Immunology Lab, Bioinformatics)",
        "Achieve 3.4+ cumulative GPA",
        "Present undergraduate research",
        "Request recommendation letters from research mentors",
        "Graduate with BS in Microbiology"
    ],
    "Phase 1: Lab Work + Prerequisites (Apr 2026 - Dec 2027)": [
        "Secure Research Associate / Lab Tech position in Utah",
        "Enroll in UC San Diego Organic Chemistry 1",
        "Complete Ochem 1 with B+ or higher",
        "Complete Biochemistry course",
        "Complete Ochem 2 (if required by target programs)",
        "Build relationships with supervisors for recommendation letters",
        "Complete Coursera specializations (Cancer Biology, Python, R)"
    ],
    "Phase 2: MS Translational Bioinformatics (Jan 2028 - Dec 2029)": [
        "Apply to University of Utah MS Biomedical Informatics (Translational Bioinformatics track)",
        "Get accepted to MS program",
        "Complete Year 1 courses (maintain 3.7+ GPA)",
        "Complete Year 2 courses + capstone project",
        "Identify capstone project (cancer genomics focus)",
        "Complete MS capstone project",
        "Graduate with MS in Translational Bioinformatics",
        "Accumulate 3.8 years total lab experience"
    ],
    "Phase 3: PhD Applications (Jun 2029 - Apr 2030)": [
        "Research PhD programs (Mayo, Utah/Huntsman, Pittsburgh, City of Hope, etc.)",
        "Contact potential advisors",
        "Request recommendation letters",
        "Take GRE (if required)",
        "Write personal statement",
        "Write research statement",
        "Submit applications (Dec 2029)",
        "Complete interviews (Jan-Mar 2030)",
        "Accept PhD offer"
    ],
    "Phase 4: PhD Program (Aug 2030 - 2035/2036)": [
        "Complete Year 1 rotations",
        "Pass written qualifying exam",
        "Select thesis advisor",
        "Pass oral qualifying exam",
        "Publish first co-authored paper",
        "Publish first first-author paper",
        "Present at national conference",
        "Apply for F31 fellowship",
        "Publish 3-5 first-author papers",
        "Write dissertation",
        "Defend dissertation",
        "Graduate with PhD"
    ]
}

# Create interactive checklist
def create_checklist():
    """Create interactive milestone checklist."""
    checklist_widgets = []
    
    for phase, items in milestones_checklist.items():
        checklist_widgets.append(widgets.HTML(f"<h4>{phase}</h4>"))
        
        for item in items:
            checkbox = widgets.Checkbox(
                value=False,
                description=item,
                indent=False,
                layout=widgets.Layout(width='100%')
            )
            checklist_widgets.append(checkbox)
        
        checklist_widgets.append(widgets.HTML("<br>"))
    
    return widgets.VBox(checklist_widgets)

# Display checklist
print("✅ Interactive Milestone Tracker:")
print("Check off milestones as you complete them!\n")
checklist = create_checklist()
display(checklist)
# Out:
# ✅ Interactive Milestone Tracker:
# Check off milestones as you complete them!
# ...

# %% [markdown]
# ## 📊 Part 7: Export Updated Roadmap

# %%
def export_timeline_summary():
    """
    Export current timeline configuration as markdown.
    """
    current_timeline = calculate_timeline()
    
    summary = f"""
# Career Roadmap Summary (Updated {datetime.now().strftime('%B %d, %Y')})

## Timeline Configuration
- **Birth Year**: {BIRTH_YEAR}
- **Phase 1 Duration**: {PHASE1_DURATION_MONTHS} months
- **MS Duration**: {MS_DURATION_YEARS} years
- **PhD Duration**: {PHD_DURATION_YEARS} years
- **Postdoc**: {'Yes' if not SKIP_POSTDOC else 'No'}

## Key Milestones

| Milestone | Date | Age |
|-----------|------|-----|
| Graduation (BS) | {current_timeline['graduation'].strftime('%B %Y')} | {current_timeline['graduation_age']} |
| Phase 1 Complete | {current_timeline['phase1_end'].strftime('%B %Y')} | {current_timeline['phase1_end_age']} |
| MS Start | {current_timeline['ms_start'].strftime('%B %Y')} | {current_timeline['ms_start_age']} |
| MS Completion | {current_timeline['ms_end'].strftime('%B %Y')} | {current_timeline['ms_end_age']} |
| Total full-time Experience | - | {current_timeline['total_mls_years']} years |
| PhD Applications | {current_timeline['phd_apply_start'].strftime('%B %Y')} | {current_timeline['phd_apply_start'].year - BIRTH_YEAR} |
| PhD Start | {current_timeline['phd_start'].strftime('%B %Y')} | {current_timeline['phd_start_age']} |
| PhD Completion | {current_timeline['phd_end'].strftime('%B %Y')} | {current_timeline['phd_end_age']} |
| Industry Career Start | {current_timeline['industry_start'].strftime('%B %Y')} | {current_timeline['industry_start_age']} |
| Senior Scientist | {current_timeline['senior_scientist'].strftime('%B %Y')} | {current_timeline['senior_scientist_age']} |
| Principal Scientist | {current_timeline['principal_scientist'].strftime('%B %Y')} | {current_timeline['principal_scientist_age']} |

## Financial Summary
- **Total Education Investment**: ${total_education_cost:,.0f}
- **Total Income During Training**: ${total_income:,.0f}
- **Net by Industry Start**: ${final_net:,.0f}

---
*Generated from Interactive Career Roadmap Notebook*
"""
    
    return summary

# Create export button
export_button = widgets.Button(
    description='📥 Export Timeline Summary',
    button_style='success',
    tooltip='Export current timeline as markdown'
)

export_output = widgets.Output()

def on_export_click(b):
    with export_output:
        export_output.clear_output()
        summary = export_timeline_summary()
        
        # Save to file
        filename = f"Career_Roadmap_Summary_{datetime.now().strftime('%Y%m%d')}.md"
        with open(filename, 'w') as f:
            f.write(summary)
        
        print(f"✅ Timeline exported to: {filename}")
        print("\nPreview:")
        display(Markdown(summary[:1000] + "..."))

export_button.on_click(on_export_click)

display(export_button)
display(export_output)
# Out:
# Button(button_style='success', description='📥 Export Timeline Summary', style=ButtonStyle(), tooltip='Export c…
# Output()

# %% [markdown]
# ## 🎯 Part 8: Quick Timeline Scenarios
#
# Compare different timeline scenarios side-by-side.

# %%
# Define scenarios
scenarios = {
    "Current Plan (3.8 years lab)": {
        "phase1": 21,
        "ms_years": 2,
        "phd_years": 5.5,
        "postdoc": False
    },
    "Faster Track (3 years lab)": {
        "phase1": 15,
        "ms_years": 2,
        "phd_years": 5,
        "postdoc": False
    },
    "Extended with Postdoc": {
        "phase1": 21,
        "ms_years": 3,
        "phd_years": 6,
        "postdoc": True
    },
    "Slower MS Track (5.3 years lab)": {
        "phase1": 21,
        "ms_years": 3,
        "phd_years": 5.5,
        "postdoc": False
    }
}

def calculate_scenario(config):
    """Calculate timeline for a specific scenario."""
    global PHASE1_DURATION_MONTHS, MS_DURATION_YEARS, PHD_DURATION_YEARS, SKIP_POSTDOC
    
    PHASE1_DURATION_MONTHS = config['phase1']
    MS_DURATION_YEARS = config['ms_years']
    PHD_DURATION_YEARS = config['phd_years']
    SKIP_POSTDOC = not config['postdoc']
    
    return calculate_timeline()

# Compare scenarios
comparison_data = []

for scenario_name, config in scenarios.items():
    result = calculate_scenario(config)
    lab_years = result['total_lab_years']
    
    comparison_data.append({
        'Scenario': scenario_name,
        'Lab Years': f"{lab_years:.1f}",
        'PhD Start Age': result['phd_start_age'],
        'PhD End Age': result['phd_end_age'],
        'Industry Start Age': result['industry_start_age'],
        'Industry Start Year': result['industry_start'].year,
        'Years from Now': result['industry_start'].year - datetime.now().year
    })

df_comparison = pd.DataFrame(comparison_data)

print("📊 Timeline Scenario Comparison:\n")
display(df_comparison)

# Visualize comparison
fig_comparison = px.bar(
    df_comparison,
    x='Scenario',
    y='Industry Start Age',
    color='Years from Now',
    title='Age at Industry Career Start - Scenario Comparison',
    text='Industry Start Age',
    color_continuous_scale='Viridis'
)

fig_comparison.update_traces(textposition='outside')
fig_comparison.update_layout(height=400)
fig_comparison.show()
# Out:
# 📊 Timeline Scenario Comparison:
#                           Scenario Lab Years  PhD Start Age  PhD End Age  \
# 0     Current Plan (3.8 years lab)       3.8             31           37
# 1       Faster Track (3 years lab)       3.3             31           36
# 2            Extended with Postdoc       4.8             32           38
# 3  Slower MS Track (5.3 years lab)       4.8             32           38
#
#    Industry Start Age  Industry Start Year  Years from Now
# 0                  37                 2036              11
# 1                  36                 2035              10
# 2                  41                 2040              15
# 3                  38                 2037              12

# %% [markdown]
# ## 💡 Notes & Reflections
#
# Use the cell below to jot down thoughts, adjustments, or insights as your career progresses.

# %%
# Personal notes and reflections
notes_area = widgets.Textarea(
    value='',
    placeholder='Add your thoughts, updates, or reflections here...',
    description='',
    layout=widgets.Layout(width='100%', height='200px')
)

save_notes_button = widgets.Button(
    description='💾 Save Notes',
    button_style='info'
)

notes_output = widgets.Output()

def save_notes(b):
    with notes_output:
        notes_output.clear_output()
        with open('career_roadmap_notes.txt', 'a') as f:
            f.write(f"\n--- {datetime.now().strftime('%Y-%m-%d %H:%M:%S')} ---\n")
            f.write(notes_area.value)
            f.write("\n")
        print("✅ Notes saved to career_roadmap_notes.txt")

save_notes_button.on_click(save_notes)

display(widgets.HTML("<h3>📝 Personal Notes & Reflections</h3>"))
display(notes_area)
display(save_notes_button)
display(notes_output)
# Out:
# HTML(value='<h3>📝 Personal Notes & Reflections</h3>')
# Textarea(value='', layout=Layout(height='200px', width='100%'), placeholder='Add your thoughts, updates, or re…
# Button(button_style='info', description='💾 Save Notes', style=ButtonStyle())
# Output()

# %% [markdown]
# ---
#
# ## 🚀 Next Steps
#
# 1. **Adjust the timeline parameters** above to explore different scenarios
# 2. **Check off milestones** as you achieve them
# 3. **Export your timeline** regularly to track how plans evolve
# 4. **Review quarterly** and adjust as life circumstances change
# 5. **Save this notebook** and re-run whenever you need to update your roadmap
#
# Remember: This is a living document. Life happens, opportunities arise, and plans evolve. The key is having a clear vision while staying flexible enough to adapt. 💪
#
# ---
#
# *Last updated: December 1, 2025*
